// %%
val html = """    <!DOCTYPE html>
    <html lang="en">
    <head>
        <meta charset="UTF-8"/>
        <meta http-equiv="X-UA-Compatible" content="IE=edge"/>
        <meta name="viewport" content="width=device-width, initial-scale=1">
        <link rel="shortcut icon" href="/favicon.ico" type="image/x-icon"/>
        <meta name="csrf-param" content="_csrf">
<meta name="csrf-token" content="-9iugFfCVRRM-LbOIBg3tRhaTMYeS3f7LvV0kU_8RUyoj-fKZ4A2RCbIgvtzLkGHNTkrv1UGPJNAsSugH5Mmeg==">
        <title>My profile</title>
        <link href="/css/bootstrap-select.min.css?v=1675336828" rel="stylesheet">
<link href="/modules/profile/assets/css/profile.css?v=1729838440" rel="stylesheet">
<link href="/css/styles/plugins/icheck/square/orange.css?v=1675336828" rel="stylesheet">
<link href="/css/styles/plugins/malihu-custom-scrollbar-plugin/jquery.mCustomScrollbar.css?v=1675336828" rel="stylesheet">
<link href="/modules/notifications/assets/css/style.css?v=1675336828" rel="stylesheet">
<link href="/assets/f834816b/css/bootstrap.min.css?v=1675341393" rel="stylesheet">
<link href="/css/site.css?v=1773748505" rel="stylesheet">
<link href="/assets/b18765c/css/font-awesome.min.css?v=1675341393" rel="stylesheet">
<link href="/assets/17a9b5f2/css/AdminLTE.min.css?v=1675341393" rel="stylesheet">
<link href="/assets/17a9b5f2/css/skins/_all-skins.min.css?v=1675341393" rel="stylesheet">
<link href="/assets/a9f8a78c/css/style.css?v=1675341393" rel="stylesheet">
<link href="/assets/27d5b46e/stylesheets/language-picker.min.css?v=1675341393" rel="stylesheet">
<link href="/assets/27d5b46e/stylesheets/flags-large.min.css?v=1675341393" rel="stylesheet">
<script src="/js/jquery-1.11.3.min.js?v=1675336828"></script>
<script src="/modules/profile/assets/js/common.js?v=1775200815"></script>
<script src="/js/commonTabs.js?v=1751435978"></script>
<script src="/modules/profile/assets/js/student.js?v=1602505023"></script>        <script>
    let APP_ENV_TEST = "";
    let APP_ENV_DEV = "";
    let APP_BASE_URL = "https://mano.vilniustech.lt";
    let LANG_CONST = {"cannotBeEmpty":"Cannot be empty","noResultsFound":"No results found","saving":"Saving...","success":"Successfully saved"};
    let AUTOSAVE_TIMER = '0';
    let AUTOSAVE_INTERVAL = "10000";
    let RECENTLY_AUTOSAVED = false;
</script>
    </head>
    <body class="skin-blue sidebar-mini fixed" ng-app="vgtu">

        <div class="wrapper">
        <div class="browser-notification" id="browser-notification">
            <div class="callout callout-warning" id="callout-warning-notification">
                Your web browser is out of date. Update your browser for more security, speed and the best experience on this site.            </div>
        </div>

        <div class="browser-notification-explorer" id="browser-notification-explorer">
            <div class="callout callout-warning" id="callout-warning-notification-explorer">
                Your web browser Internet explorer is not supported. Use another browser for more security, speed and the best experience on this site.            </div>
        </div>

        <div class="notification-student-gone" id="notificationStudentGone">
            <div class="callout callout-warning" id="callout-warning">
                The student is currently studying / doing an internship in another country (institution)            </div>
        </div>

        <header class="main-header">
    <a href="/site/index" class="logo">
        <span class="logo-mini">
            <img class="main_logo" src="/assets/17a9b5f2/img/logo_m.png">
        </span>
        <div class="logo-lg logo-container">
            <div class="logo-container__logo-block">
                <img class="main_logo" src="/assets/17a9b5f2/img/logo_d.png">
            </div>
            <div class="logo-container__lecture-time-block">
                                    <div class="hidden_lang">
                        <input type="hidden" name="hidden_lang" value="en">                    </div>
                    <div class="lecture_time">
                        <div class="lecture_time__date-container">
                            <div class="date">
                                2026-04-07 -                             </div>
                            <div class="week">
                                week 2                            </div>
                        </div>
                        <div class="lecture lecture-time-container"></div>
                    </div>
                            </div>
        </div>
    </a>

    <nav class="navbar navbar-static-top" role="navigation">
        <a href="#" class="sidebar-toggle sidebar-nav-style" data-toggle="offcanvas" role="button">
            <span class="sr-only">Main menu</span>
        </a>
                    <div class="hidden_lang">
                <input type="hidden" name="hidden_lang" value="en">            </div>
            <div class="lecture_time">
                <span class="date">
                    2026-04-07                </span>
                <span class="week">
                week 2                </span>
                <div class="lecture lecture-time-container"></div>
            </div>
                <div class="navbar-custom-menu navbar-meniu-style">
            <ul class="nav navbar-nav">

<li>
    <a href="/contacts/contacts"
       title="Contacts">
        <i class="fa fa-address-book"></i>
    </a>
</li>

<li>
    <a href="/site/sitemap" title="Sitemap">
        <i class="fa fa-sitemap"></i>
    </a>
</li>

<li class="dropdown messages-menu" id="site-language">
    <a class="dropdown-toggle" aria-expanded="true" href="#" data-toggle="dropdown"
       title="Language">
        <i class="fa fa-language" aria-hidden="true" title="Language"></i>
    </a>
    <ul class="dropdown-menu" style="width: 230px;">
        <li class="header" style="font-size: 13px;">Default language</li>
        <li>
            <ul class="menu" id="languageListContents">
                <li><a href="#" title="en" class="link-bt back-color"><i id="en"></i> English</a></li><li><a href="/profile/site/index?language-picker-language=lt&id=20222136" title="lt" class="link-bt"><i class="lt"></i> Lietuvių</a></li>            </ul>
        </li>
    </ul>
</li>
    <li class="dropdown messages-menu" id="vgtu-mail">
        <a class="dropdown-toggle" aria-expanded="true" href="#" data-toggle="dropdown"
           title="E. mail">
            <i class="fa fa-envelope-o"></i>
        </a>
        <ul class="dropdown-menu">
            <li>
                <ul class="menu" id="mailListContents">
                                                                                    <li>
                            <a href="https://outlook.office.com"
                               target="_blank">
                                <div class="pull-left">
                                    <img class="img-circle" src="/images/outlook-icon.png">
                                </div>
                                <h4 style="color: #000000 !important; font-weight: bold;">Danila Gudim</h4>

                                <p>danila.gudim@stud.vilniustech.lt</p>
                            </a>
                        </li>
                                    </ul>
            </li>
        </ul>
    </li>

<div id="notification-modal" class="fade modal" role="dialog">
<div class="modal-dialog modal-notifications-lg">
<div class="modal-content">
<div class="modal-header">
<button type="button" class="close" data-dismiss="modal" aria-hidden="true">&times;</button>
<i></i><span id="notification-title"></span>
</div>
<div class="modal-body">
<div id='notification-container'></div><div class='tabs-overlay dn' id='notifications-view-overlay'><i class='fa fa-refresh fa-spin'></i></div>
</div>

</div>
</div>
</div><li class="dropdown notifications-menu" id="notifications-dropdown">
    <a href="#" class="dropdown-toggle dropdown-toggle-style" data-toggle="dropdown" id="notifications-dropdown-btn">
        <i class="fa fa-bell-o"></i>
        <span class="label label-warning count-notifications">5</span>
    </a>
    <ul class="dropdown-menu dropdown-toggle-style" id="notifications-dropdown-content">
        <li id="notifications-overlay">
            <i class="fa fa-refresh fa-spin"></i>
        </li>
    </ul>
</li>
                <!--<li class="dropdown tasks-menu">
    <a href="#" class="dropdown-toggle" data-toggle="dropdown">
        <i class="fa fa-flag-o"></i>
        <span class="label label-danger">9</span>
    </a>
    <ul class="dropdown-menu">
        <li class="header">You have 9 tasks</li>
        <li>
            <ul class="menu">
                <li>
                    <a href="#">
                        <h3>
                            Design some buttons
                            <small class="pull-right">20%</small>
                        </h3>
                        <div class="progress xs">
                            <div class="progress-bar progress-bar-aqua" style="width: 20%"
                                 role="progressbar" aria-valuenow="20" aria-valuemin="0"
                                 aria-valuemax="100">
                                <span class="sr-only">20% Complete</span>
                            </div>
                        </div>
                    </a>
                </li>

                <li>
                    <a href="#">
                        <h3>
                            Create a nice theme
                            <small class="pull-right">40%</small>
                        </h3>
                        <div class="progress xs">
                            <div class="progress-bar progress-bar-green" style="width: 40%"
                                 role="progressbar" aria-valuenow="20" aria-valuemin="0"
                                 aria-valuemax="100">
                                <span class="sr-only">40% Complete</span>
                            </div>
                        </div>
                    </a>
                </li>

                <li>
                    <a href="#">
                        <h3>
                            Some task I need to do
                            <small class="pull-right">60%</small>
                        </h3>
                        <div class="progress xs">
                            <div class="progress-bar progress-bar-red" style="width: 60%"
                                 role="progressbar" aria-valuenow="20" aria-valuemin="0"
                                 aria-valuemax="100">
                                <span class="sr-only">60% Complete</span>
                            </div>
                        </div>
                    </a>
                </li>

                <li>
                    <a href="#">
                        <h3>
                            Make beautiful transitions
                            <small class="pull-right">80%</small>
                        </h3>
                        <div class="progress xs">
                            <div class="progress-bar progress-bar-yellow" style="width: 80%"
                                 role="progressbar" aria-valuenow="20" aria-valuemin="0"
                                 aria-valuemax="100">
                                <span class="sr-only">80% Complete</span>
                            </div>
                        </div>
                    </a>
                </li>
            </ul>
        </li>
        <li class="footer">
            <a href="#">View all tasks</a>
        </li>
    </ul>
</li>-->                <li class="dropdown user user-menu">
    <a href="#" class="dropdown-toggle" data-toggle="dropdown" id="user-menu-mini-foto">
        <img class="profile-user-img img-responsive img-circle user-photo"
             alt="Danila Gudim" src="/photos/20222136.jpg">
        <span class="hidden-xs">
            Danila Gudim        </span>
    </a>
    <ul class="dropdown-menu">
        <li class="user-header">
            <img class="profile-user-big-img img-responsive img-circle user-photo"
                 alt="Danila Gudim" src="/photos/20222136.jpg">
            <p>Danila Gudim</p>
        </li>
        <li class="user-footer">
            <div class="pull-left">
                <a class="btn btn-default btn-flat" href="/profile/site">My profile</a>            </div>
            <div class="pull-right">
                <a href="/user/logout" class="btn btn-default btn-flat">
                    Logout                </a>
            </div>
        </li>
    </ul>
</li>
                <li class="settings-menu">
                    <a href="#" data-toggle="control-sidebar" title="Settings">
                        <i class="fa fa-gears"></i>
                    </a>
                </li>
            </ul>
        </div>
    </nav>
</header>

        <aside class="main-sidebar">
            <section class="sidebar">
                <ul class="sidebar-menu">
    <!-- Home -->
        <li>
        <a href="/site/index">
            <i class="fa fa-home"></i>
            <span>Dashboard</span>
        </a>
    </li>
            <li class="main-menu-studies">
        <a href="#">
    <i class="fa fa-graduation-cap"></i> <span>Studies</span>
    <i class="fa fa-angle-right pull-right"></i>
</a>
<ul class="treeview-menu studies-left-tab">
                <li>
            <a href="/thissemester/site/loadindex">
                <div class="word-wrap-block">
                    <i class="menu_dot"></i>
                    This semester                </div>
                <i class="fa fa-angle-right pull-right"></i></a>
            <ul class="treeview-menu">
                </li>
            </ul>
        </li>
                    <li>
                <a href="/program/site">
                    <i class="menu_dot"></i>
                    Study programme                </a>
            </li>
                <li>
            <a href="/results/site">
                <div class="word-wrap-block">
                    <i class="menu_dot"></i>
                    My results                </div>
            </a>
        </li>
                <li>
            <a href="/thesis/site">
                <div class="word-wrap-block">
                    <i class="menu_dot"></i>
                    Thesis subject                </div>
            </a>
        </li>
            <li>
        <a href="/examstimetable/exams">
            <div class="word-wrap-block">
                <i class="menu_dot"></i>
                Exams timetable            </div>
        </a>
    </li>
        <li>
        <a href="/studyprograms/site">
            <div class="word-wrap-block">
                <i class="menu_dot"></i>
                All programs            </div>
        </a>
    </li>
            <li>
            <a href="/practices/site/practice-information">
                <div class="word-wrap-block">
                    <i class="menu_dot"></i>
                    Internships                </div>
            </a>
        </li>
        <li>
        <a href="/auditoccupancy/auditoccupancy">
            <div class="word-wrap-block">
                <i class="menu_dot"></i>
                Auditorium Occupancy            </div>
        </a>
    </li>
    <li>
        <a href="/timetable/site/search-form">
            <div class="word-wrap-block">
                <i class="menu_dot"></i>
                Lecture schedule            </div>
        </a>
    </li>
        <li>
        <a href="/lecturerconsult/consult/consult">
            <div class="word-wrap-block">
                <i class="menu_dot"></i>
                Lecturer's consultation            </div>
        </a>
    </li>
    <li>
                    <a href="/studyreport/site">
                <div class="word-wrap -block">
                    <i class="menu_dot"></i>
                    Study programme report                </div>
            </a>
            </li>
	</ul>
    </li>
    <li class="main-menu-study-process">
            <a href="#">
        <i class="fa fa-bullhorn"></i> <span>Study procedure</span>
        <i class="fa fa-angle-right pull-right"></i>
    </a>
    <ul class="treeview-menu">
        <li>
            <a href="/studyprocess/rates">
                <i class="menu_dot"></i>
                Academic ethics            </a>
        </li>
        <li>
            <a href="/studyprocess/lectures">
                <i class="menu_dot"></i>
                Time of lectures            </a>
        </li>
        <li>
            <a href="/studyprocess/settlements">
                <i class="menu_dot"></i>
                Middle tests, homework and course projects            </a>
        </li>
        <li>
            <a href="/studyprocess/session">
                <i class="menu_dot"></i>
                Exam Session            </a>
        </li>
        <li>
            <a href="/studyindividualization/site/index">
                <i class="menu_dot"></i>
                Adjustment of studies            </a>
        </li>
        <li>
            <a href="/studyprocess/workreq">
                <i class="menu_dot"></i>
                Written work requirements            </a>
        </li>
        <li>
            <a href="/studyprocess/reviews">
                <i class="menu_dot"></i>
                Grading system            </a>
        </li>
        <li>
            <a href="/studyprocess/appeals">
                <i class="menu_dot"></i>
                Appeals            </a>
        </li>
                <li>
            <a href="/studyprocess/scholarships">
                <i class="menu_dot"></i>
                Scholarships            </a>
        </li>
        <li>
            <a href="/studyprocess/finals">
                <i class="menu_dot"></i>
                Final works            </a>
        </li>
    </ul>
    </li>
    <li class="main-menu-software">
        <a href="/itservices/site">
    <i class="fa fa-cog"></i>
    <span>IT services</span>
</a>
    </li>
    <li class="main-menu-library">
        <a href="/library/site">
    <i class="fa fa-book"></i>
    <span>Library</span>
</a>
    </li>
    <li class="main-menu-career">
            <a href="/mycareer">
        <i class="fa fa-suitcase"></i>
        <span>My career</span>
        <i class="fa fa-angle-right pull-right"></i>
    </a>
    <ul class="treeview-menu">
        <li>
            <a href="/mycareer/careerplanning">
                <i class="menu_dot"></i>
                Career planning advice            </a>
        </li>
        <li>
            <a href="/mycareer/practiceconsult">
                <i class="menu_dot"></i>
                Internship consultation            </a>
        </li>
        <li>
            <a href="/mycareer/careerday">
                <i class="menu_dot"></i>
                VILNIUS TECH career days            </a>
        </li>
        <li>
            <a href="/mycareer/jobs">
                <i class="menu_dot"></i>
                Job offers            </a>
        </li>
        <li>
            <a href="/mycareer/practices">
                <i class="menu_dot"></i>
                Internship offers            </a>
        </li>
        <li>
            <a href="/mycareer/contacts">
                <i class="menu_dot"></i>
                Contacts            </a>
        </li>
    </ul>
    </li>
    <li class="main-menu-international">
            <a href="/international">
        <i class="fa fa-newspaper-o"></i>
        <span>International opportunities</span>
        <i class="fa fa-angle-right pull-right"></i>
    </a>
    <ul class="treeview-menu">
                    <li>
                <a href="#">
                    <i class="menu_dot"></i>
                    Erasmus+ study exchange                    <i class="fa fa-angle-right pull-right"></i>
                </a>
                <ul class="treeview-menu">
                    <li>
                        <a href="/international/international/erasmusstudyinfo">
                            <i class="menu_dot"></i>
                            Information                        </a>
                    </li>
                    <li>
                        <a href="/international/mobility/student-outside-eu">
                            <i class="menu_dot"></i>
                            Apply for studies outside EU                        </a>
                    </li>
                    <li>
                        <a href="/international/mobility/student">
                            <i class="menu_dot"></i>
                            Apply for studies within EU                        </a>
                    </li>
                    <li>
                        <a href="/international/international/studiesapplications">
                            <i class="menu_dot"></i>
                            My applications                        </a>
                    </li>
                </ul>
            </li>
            <li>
                <a href="#">
                    <i class="menu_dot"></i>
                    Erasmus+ internship                    <i class="fa fa-angle-right pull-right"></i>
                </a>
                <ul class="treeview-menu">
                    <li>
                        <a href="/international/international/erasmuspracticeinfo">
                            <i class="menu_dot"></i>
                            Information                        </a>
                    </li>
                    <!--Disabled by URD request-->
                    <!--<li>
                        <a href="">
                            <i class="menu_dot"></i>
                                                    </a>
                    </li>-->
                    <li>
                        <a href="/internship/submission">
                            <i class="menu_dot"></i>
                            Apply for internship                        </a>
                    </li>
                </ul>
            </li>
            <li>
                <a href="/international/international/internationalopportunities">
                    <i class="menu_dot"></i>
                    Other international opportunities                </a>
            </li>
                    </ul>
    </li>
    <li class="main-menu-life-in-vgtu">
        <a href="#">
    <i class="fa fa-university"></i>
    <span>Life in VILNIUS TECH</span>
    <i class="fa fa-angle-right pull-right"></i>
</a>
<ul class="treeview-menu">
                    <li>
            <a href="/vgtulife/learnparticipate">
                <i class="menu_dot"></i>
                Event and Activities            </a>
        </li>
    <!-- Disabled. More info Redmine.   -->
<!--    <li>-->
<!--        <a href="--><!--">-->
<!--            <i class="menu_dot"></i>-->
<!--            --><!--        </a>-->
<!--    </li>-->
<!--    <li>-->
<!--        <a href="#"><i class="menu_dot"></i>-->
<!--            --><!--            <i class="fa fa-angle-right pull-right"></i>-->
<!--        </a>-->
<!--        <ul class="treeview-menu">-->
<!--            <li>-->
<!--                <a href="-->
<!--                --><!--" target="_blank"><i-->
<!--                            class="menu_dot"></i>-->
<!--                    --><!--                </a>-->
<!--            </li>-->
<!--            --><!--            --><!--                <li>-->
<!--                    <a href="--><!--">-->
<!--                        <i class="menu_dot"></i>-->
<!--                        --><!--                    </a>-->
<!--                </li>-->
<!--            --><!--        </ul>-->
<!--    </li>-->
<!--    Uncomment if will be needed, issue with having two same menus is they both open and highlight.-->
<!--    <li>-->
<!--        <a href="--><!--" class="no-highlight">-->
<!--            <i class="menu_dot"></i>--><!--        </a>-->
<!--    </li>-->
        <li>
        <a href="#">
            <i class="menu_dot"></i>
            Accommodation            <i class="fa fa-angle-right pull-right"></i>
        </a>
        <ul class="treeview-menu">
            <li>
                <a href="/hostel/site">
                    <i class="menu_dot"></i>
                    Dormitory information                </a>
            </li>
                                                <li>
                        <a href="/hostel/international/index">
                            <i class="menu_dot"></i>
                            Request a dormitory                        </a>
                    </li>
                                    </ul>
    </li>
        <li>
        <a href="/vgtulife/maps">
            <i class="menu_dot"></i>VILNIUS TECH maps        </a>
    </li>
</ul>
    </li>
        <li class="main-menu-documents">
            <a href="#">
        <i class="fa fa-files-o"></i>
        <span>My documents</span>
        <i class="fa fa-angle-right pull-right"></i>
    </a>
    <ul class="treeview-menu">
                                <li>
                            <a href="/requests/site">
                                <i class="menu_dot"></i>
                                Requests                                                            </a>
                                                    </li>
                                                <li>
                            <a href="/documentation/studyfees">
                                <i class="menu_dot"></i>
                                Fees for studies                                                            </a>
                                                    </li>
                                                <li>
                            <a href="/documentation/certificates">
                                <i class="menu_dot"></i>
                                Certificates                                                            </a>
                                                    </li>
                                                <li>
                            <a href="/documentation/final-report-slip">
                                <i class="menu_dot"></i>
                                Final report slip                                                            </a>
                                                    </li>
                                                <li>
                            <a href="/documentsapproval/site">
                                <i class="menu_dot"></i>
                                Documents for approval                                                            </a>
                                                    </li>
                                                <li>
                            <a href="/requests/other">
                                <i class="menu_dot"></i>
                                Other                                                            </a>
                                                    </li>
                            </ul>
    </li>
                <li class="main-menu-surveys">
            <a href="#">
    <i class="fa fa-clone"></i>
    <span>Surveys</span>
    <i class="fa fa-angle-right pull-right"></i>
</a>
<ul class="treeview-menu">
        <li>
        <a href="/surveys/results">
            <i class="menu_dot"></i>
            Results of the student survey on the quality of teaching        </a>
    </li>
    </ul>        </li>

        <li class='main-menu-covid'>
        <a href="/announcement/site/index">
    <i class='fa fa-medkit'></i>
    <span>Safety at VILNIUS TECH</span>
</a>
    </li>
	<li class="main-menu-contacts">
        <a href="/contacts/contacts">
    <i class="fa fa-address-book"></i>
    <span>Contacts</span>
</a>    </li>
</ul>
            </section>
        </aside>

        <script>
    $(function () {
        if (window.location.pathname === '/') {
            $('.active').removeClass('active');
        }
    });

    let linkElement = $('a[href="' + window.location.pathname + '"]');
    let treeView = linkElement.closest('.treeview');

    treeView.addClass('active');
    //open main treeview
    treeView.parent('ul').addClass('menu-open').css('display', 'block');

    // Recursively adds active class to all parent 'li' elements. Works for regular links, as well as those in treeview class.
    $.each(linkElement.parents('li'), function() {
        $(this).addClass('active');
    });

    //do not delete.
    //    $("a[href$="" + window.location.pathname + ""]").parent('li').parent('ul').parent('li').find('.treeview-menu').addClass('menu-open');
    //    $("a[href$="" + window.location.pathname + ""]").parent('li').parent('ul').parent('li').find('.treeview-menu').css('display', 'block');
    //do not delete.

    $(".loadonclick").click(function () {
        $(".content").fadeOut();
    });

    $(function () {
        // changed id to class
        $('.users-activity').click(function () {
            $.get($(this).attr('href'), function (data) {
                var modal = $('#modal');
                var modal_header = $('div#modal div.modal-content div#modalHeader');
                var modal_body = $('div#modal div.modal-content div.modal-body');
                var modal_footer = $('div#modal div.modal-content div.modal-footer');

                $(modal_header).html('&nbsp &nbsp' + getUserInformationHeader() + getButtonx());
                $(modal_body).html(data);
                modal_body.find('.usersinformation').css({"padding-top": "15px", "padding-bottom": "15px"});
                $(modal).modal('show');
            });
            return false;
        });
    });

    function getUserInformationHeader() {
        var header = 'Recent account activity';
        return header;
    }

</script>
<div class="content-wrapper">
    <section class="content-header">
        <h1>
            My profile        </h1>
        <ul class="breadcrumb"><li><a href="/">Dashboard</a></li>
<li class="active">My profile</li>
</ul>    </section>
    <section class="content">
                <div id="message"></div>
                <div class="row">
    <div class="col-lg-3 col-md-4">
        <div class="row">
        <div class="col-md-12 col-sm-6">
            <div  id="bc_w2" class="box box-default"><div class="box-body"><div id="photo-container-id" class="photo-container">
    <div class="loader-photo"></div>
    <div id="upload-container">
        <span id="imageUpload"></span>
        <input type="file" name="file" accept="image/*" id="browse">
    </div>
    <div id="imageDelete" class="delete-photo "></div>
    <img id="user_img_id" class="profile-user-img img-responsive img-circle user-photo"
         alt="Danila Gudim" src="/photos/20222136.jpg">
    <h3 class="profile-username text-center">
        Danila Gudim    </h3>
</div>
<div class="clear"></div>
<br>
<div id="photo-error" class="photo-error-st"></div>
<div class="mb20"></div>
</div></div>        </div>
        <div class="col-md-12 col-sm-6">
            <form id="student-personal-info" action="/profile/student/edit-personal-info" method="post" data-loader-class="student-overlay" messages-action="/site/show-messages">
<input type="hidden" name="_csrf" value="-9iugFfCVRRM-LbOIBg3tRhaTMYeS3f7LvV0kU_8RUyoj-fKZ4A2RCbIgvtzLkGHNTkrv1UGPJNAsSugH5Mmeg=="><div  id="bc_w3" class="box box-default"><div class="box-header with-border"><h3 class="box-title">About me</h3></div><div class="box-body"><table class="table">
    <tbody>
    <tr class="border-color-bott">
        <td class="border-none">
            Birth date        </td>
        <td class="border-none color-black">
            April 24            d.
        </td>
        <td class="border-none px-0">
            <select name="show_date" class="selectpicker show-tick" data-width="55px" data-style="custom-acc-select">
                <option data-icon="fa fa-lock"
                        value="0" >
                    For me only                </option>
                <option data-icon="fa fa-users"
                        value="1" selected>
                    #For group#                </option>
            </select>
        </td>
    </tr>
    <tr class="border-bottom-none">
        <td class="border-none">
            Birthyear        </td>
        <td class="border-none color-black">
            2004 m.
        </td>
        <td class="border-none"></td>
    </tr>
    </tbody>
</table>
<button type="submit" class="btn btn-info pull-right">Save</button><div class="overlay display-none" id="student-overlay">
    <i class="fa fa-refresh fa-spin"></i>
</div>
</div></div></form>        </div>
        </div>
    </div>
    <div class="col-lg-9 col-md-8">
        <div class="tabs-x nav-tabs-custom horizontalTab" id="studentHorizontalTab">
            <ul class="nav custom-tabs nav-tabs tabx-resp resp-tabs-list hor_1" id="student_global_tabs">
                <li class="custom-tabs">
                    <a href="#student-contacts" data-toggle="tab" data-url="student/contacts">
                        Contacts                    </a>
                </li>
                                    <li class="custom-tabs">
                        <a aria-expanded="false" href="#student-bank" data-toggle="tab" data-url="student/bank">
                            Bank account                        </a>
                    </li>
                    <li class="custom-tabs">
                        <a aria-expanded="false" href="#student-password" data-toggle="tab" data-url="student/password">
                            Change password                        </a>
                    </li>
                                <li class="custom-tabs">
                    <a aria-expanded="false" href="#student-rfid" data-toggle="tab" data-url="student/rfid">
                        RFID                    </a>
                </li>
            </ul>
            <div class="tab-content resp-tabx-content relative">
                <div class="resp-tabs-container hor_1">
                    <div class="tab-pane" id="student-contacts"></div>
                                            <div class="tab-pane" id="student-bank"></div>
                        <div class="tab-pane" id="student-password"></div>
                                        <div class="tab-pane" id="student-rfid"></div>
                </div>
                <div class="tabs-overlay display-none" id="studentHorizontalTab-overlay">
                    <i class="fa fa-refresh fa-spin"></i>
                </div>
            </div>
        </div>
    </div>
</div>    </section>
</div>
<footer class="main-footer">
    <ul class="footer-wrapper">
                    <li class="faculty_ft">
                <p>
                    <a href="http://www.vgtu.lt/faculties/6157"
                       class="faculty" target="_blank">
                        Faculty of Fundamental Sciences                    </a>
                    &nbsp; |</p>
            </li>
                <li class="social-icons">
            <a class="social-fb" href="https://www.facebook.com/vilniustech/" target="_blank"></a>
            <a class="social-youtube" href="https://www.youtube.com/channel/UCW4UCKB80NlgnD7SBJZMAlQ" target="_blank"></a>
            <a class="social-linkedin" href="https://www.linkedin.com/school/vilniustech/" target="_blank"></a>
            <a class="social-instagram" href="https://www.instagram.com/vilniustech/" target="_blank"></a>
        </li>
        <li class="copyrights">© VILNIUS TECH ITSC 2026</li>
    </ul>
</footer>
<aside class="control-sidebar control-sidebar-light">
    <div class="tab-content">
                <h4 class="control-sidebar-heading">
            Skins        </h4>
        <ul class="list-unstyled clearfix">
            <li class="skins-list">
                <a class="clearfix full-opacity-hover skin-link" href="javascript:void(0)" data-skin="skin-blue">
                    <div>
                        <span class="skin-span-block span-20-7 head-blue"></span>
                        <span class="bg-light-blue skin-span-block span-80-7"></span>
                    </div>
                    <div>
                        <span class="skin-span-block span-20-20 head-blue"></span>
                        <span class="skin-span-block span-80-20 head-grey-d"></span>
                    </div>
                </a>
                <p class="text-center no-margin text">
                    Blue                </p>
            </li>
            <li class="skins-list">
                <a class="clearfix full-opacity-hover skin-link" href="javascript:void(0)" data-skin="skin-black">
                    <div class="clearfix skin-d-shad">
                        <span class="skin-span-block span-20-7 head-black"></span>
                        <span class="skin-span-block span-80-7 head-black"></span>
                    </div>
                    <div>
                        <span class="skin-span-block span-20-20 head-black"></span>
                        <span class="skin-span-block span-80-20 head-grey-d"></span>
                    </div>
                </a>
                <p class="text-center no-margin text">
                    Black                </p>
            </li>
            <li class="skins-list">
                <a class="clearfix full-opacity-hover skin-link" href="javascript:void(0)" data-skin="skin-purple">
                    <div>
                        <span class="bg-purple-active skin-span-block span-20-7"></span>
                        <span class="bg-purple skin-span-block span-80-7"></span>
                    </div>
                    <div>
                        <span class="skin-span-block span-20-20 head-grey"></span>
                        <span class="skin-span-block span-80-20 head-grey-d"></span>
                    </div>
                </a>
                <p class="text-center no-margin text">
                    Purple                </p>
            </li>
            <li class="skins-list">
                <a class="clearfix full-opacity-hover skin-link" href="javascript:void(0)" data-skin="skin-green">
                    <div>
                        <span class="bg-green-active skin-span-block span-20-7"></span>
                        <span class="bg-green skin-span-block span-80-7"></span>
                    </div>
                    <div>
                        <span class="skin-span-block span-20-20 head-grey"></span>
                        <span class="skin-span-block span-80-20 head-grey-d"></span>
                    </div>
                </a>
                <p class="text-center no-margin text">
                    Green                </p>
            </li>
            <li class="skins-list">
                <a class="clearfix full-opacity-hover skin-link" href="javascript:void(0)" data-skin="skin-red">
                    <div>
                        <span class="bg-red-active skin-span-block span-20-7"></span>
                        <span class="bg-red skin-span-block span-80-7"></span>
                    </div>
                    <div>
                        <span class="skin-span-block span-20-20 head-grey"></span>
                        <span class="skin-span-block span-80-20 head-grey-d"></span>
                    </div>
                </a>
                <p class="text-center no-margin text">
                    Red                </p>
            </li>
            <li class="skins-list">
                <a class="clearfix full-opacity-hover skin-link" href="javascript:void(0)" data-skin="skin-yellow">
                    <div>
                        <span class="bg-yellow-active skin-span-block span-20-7"></span>
                        <span class="bg-yellow skin-span-block span-80-7"></span>
                    </div>
                    <div>
                        <span class="skin-span-block span-20-20 head-grey"></span>
                        <span class="skin-span-block span-80-20 head-grey-d"></span>
                    </div>
                </a>
                <p class="text-center no-margin text">
                    Yellow                </p>
            </li>
            <li class="skins-list">
                <a class="clearfix full-opacity-hover skin-link" href="javascript:void(0)" data-skin="skin-blue-light">
                    <div>
                        <span class="skin-span-block span-20-7 head-blue"></span>
                        <span class="bg-light-blue skin-span-block span-80-7"></span>
                    </div>
                    <div>
                        <span class="skin-span-block span-20-20 head-grey-ddd"></span>
                        <span class="skin-span-block span-80-20 head-grey-d"></span>
                    </div>
                </a>
                <p class="text-center no-margin text">
                    Blue Light                </p>
            </li>
            <li class="skins-list">
                <a class="clearfix full-opacity-hover skin-link" href="javascript:void(0)" data-skin="skin-black-light">
                    <div class="clearfix skin-d-shad">
                        <span class="skin-span-block span-20-7 head-grey-dd"></span>
                        <span class="skin-span-block span-80-7 head-grey-dd"></span>
                    </div>
                    <div>
                        <span class="skin-span-block span-20-20 head-grey-ddd"></span>
                        <span class="skin-span-block span-80-20 head-grey-d"></span>
                    </div>
                </a>
                <p class="text-center no-margin text">
                    Grey Light                </p>
            </li>
            <li class="skins-list">
                <a class="clearfix full-opacity-hover skin-link" href="javascript:void(0)"
                   data-skin="skin-purple-light">
                    <div>
                        <span class="bg-purple-active skin-span-block span-20-7"></span>
                        <span class="bg-purple skin-span-block span-80-7"></span>
                    </div>
                    <div>
                        <span class="skin-span-block span-20-20 head-grey-ddd"></span>
                        <span class="skin-span-block span-80-20 head-grey-d"></span>
                    </div>
                </a>
                <p class="text-center no-margin text">
                    Purple Light                </p>
            </li>
            <li class="skins-list">
                <a class="clearfix full-opacity-hover skin-link" href="javascript:void(0)" data-skin="skin-green-light">
                    <div>
                        <span class="bg-green-active skin-span-block span-20-7"></span>
                        <span class="bg-green skin-span-block span-80-7"></span>
                    </div>
                    <div>
                        <span class="skin-span-block span-20-20 head-grey-ddd"></span>
                        <span class="skin-span-block span-80-20 head-grey-d"></span>
                    </div>
                </a>
                <p class="text-center no-margin text">
                    Green Light                </p>
            </li>
            <li class="skins-list">
                <a class="clearfix full-opacity-hover skin-link" href="javascript:void(0)" data-skin="skin-red-light">
                    <div>
                        <span class="bg-red-active skin-span-block span-20-7"></span>
                        <span class="bg-red skin-span-block span-80-7"></span>
                    </div>
                    <div>
                        <span class="skin-span-block span-20-20 head-grey-ddd"></span>
                        <span class="skin-span-block span-80-20 head-grey-d"></span>
                    </div>
                </a>
                <p class="text-center no-margin text">
                    Red Light                </p>
            </li>
            <li class="skins-list">
                <a class="clearfix full-opacity-hover skin-link" href="javascript:void(0)"
                   data-skin="skin-yellow-light">
                        <span class="bg-yellow-active skin-span-block span-20-7"></span>
                    <div>
                        <span class="skin-span-block span-20-20 head-grey-ddd"></span>
                        <span class="skin-span-block span-80-20 head-grey-d"></span>
                    </div>
                </a>
                    Yellow Light                </p>
            </li>
        </ul>
    </div>
</aside>
<div class='control-sidebar-bg'></div>
                    <div class="button" id="feedback-btn">
                <a id="feedback-click" href="https://pagalba.vilniustech.lt/study-help?auth=1">
                    <i class="fa fa-comments-o action-btn-size" aria-hidden="true"></i>
                    Need help? (dormitories,  studies and other issues)                </a>
                <a id="feedback-close" onclick="removeButton();" href="javascript:void(0)">
            </div>
<script src="/js/bluebird.min.js?v=1675336828"></script>
<script src="/modules/notifications/assets/js/notifications.js?v=1675336828"></script>
<script src="/assets/e5e7aa1/en.js?v=1775566203"></script>
<script src="/assets/ba3638f3/javascripts/md5.js?v=1675341392"></script>
<script src="/assets/ba3638f3/javascripts/lajax.js?v=1675341392"></script>
<script src="/assets/70427f0c/jquery.js?v=1675341393"></script>
<script src="/js/bootstrap-select.min.js?v=1675336828"></script>
<script src="/assets/cc4f0ddb/yii.js?v=1675341393"></script>
<script src="/assets/cc4f0ddb/yii.activeForm.js?v=1675341393"></script>
<script src="/js/bootstrap-tabs-x.js?v=1675336828"></script>
<script src="/js/icheck.js?v=1675336828"></script>
<script src="/js/jquery.mCustomScrollbar.concat.min.js?v=1675336828"></script>
<script src="/js/jquery.slimscroll.min.js?v=1675336828"></script>
<script src="/js/easyResponsiveTabs.js?v=1675336828"></script>
<script src="/js/browserVersionCheck.js?v=1675336828"></script>
<script src="/assets/f834816b/js/bootstrap.min.js?v=1675341393"></script>
<script src="/assets/17a9b5f2/js/app.min.js?v=1675341393"></script>
<script src="/assets/17a9b5f2/js/demo.js?v=1675341393"></script>
<script src="/assets/a9f8a78c/js/feedback.js?v=1675341393"></script>
        <script>
        $(window).load(function () {
            var url = '/profile/site/index';
            $('#check').modal('show');

        });

        // Modal code
        $(document).on('click', '.showModalButton', function () {
            var spinner = loadSpinner();

            if ($('#modal').modal('show').isShown) {
                $('#modal').find('.modal-body').load($(this).attr('value'));
                document.getElementById('modalHeader').innerHTML = '<span>' + $(this).attr('title') + '</span>';
            } else {
                $('#modal').modal('show').find('.modal-body').load($(this).attr('value'));
                console.log($(this).attr('title'));
                document.getElementById('modalHeader').innerHTML = '<span>' + $(this).attr('title') + '</span>';
            }
        });

        $(document).on('click', '.responsive-table tr', function () {
            if ($(this).find('span').data('name') === 'showModal') {
                let spinner = loadSpinner();
                let modal = $('#modal');
                modal.find('.modal-body').html(spinner);

                if (modal.modal('show').isShown) {
                    modal.find('.modal-body').load($(this).find('span').data('url'));
                } else {
                    modal.modal('show').find('.modal-body').load($(this).find('span').data('url'));
                }

                $('#modalHeader').html('<span>' + $(this).find('span').data('title') + '</span>');
            }
        });

        function loadSpinner() {
            return '<div id=\'modalContent\'><div style=\'text-align:center\'><i class="fa fa-refresh fa-spin" style="font-size: 30px;"></i></div></div>';
        }
    </script>
    </body>
    </html>

<div id="modal" class="fade modal" role="dialog" tabindex="-1">
<div class="modal-dialog modal-lg">
<div class="modal-content">
<div id="modalHeader" class="modal-header">
<button type="button" class="close" data-dismiss="modal" aria-hidden="true">&times;</button>
<span id="modalHeaderTitle"></span>
</div>
<div class="modal-body">
<div id='modalContent'><div style='text-align:center'><i class="fa fa-refresh fa-spin" style="font-size: 30px;"></i></div></div>
</div>
<div class="modal-footer">
<a href="#" class="btn btn-vgtu-close" data-dismiss="modal">Close</a>
</div>
</div>
</div>
</div>"""



private fun String.cleanHttpResponse(): String {
    return replace("&amp;", "&")
        .replace("\\\"", "\"")
        .replace("\\/", "/")
}

private fun String.singleLine(): String {
    return replace("\n", "")
}

fun Regex.findFirstGroup(str: String): String? {
    return find(str)?.groupValues?.get(1)?.trim()
}

val fullNameAndAvatarExtractionRegex =
    Regex("""id="user_img_id".*?alt="(.*?)".*?src="(.*?)"""", RegexOption.MULTILINE)

val birthDateExtractionRegex =
    Regex(
        """Birth date .*?<td class="border-none color-black">(.*?)<""",
        RegexOption.MULTILINE
    )
val birthYearExtractionRegex =
    Regex(
        """Birthyear .*?<td class="border-none color-black">(.*?)<""",
        RegexOption.MULTILINE
    )

val basePageResponseContent = html.singleLine()

val birthDate =
    birthDateExtractionRegex.findFirstGroup(basePageResponseContent)?.replace("d.", "")
        ?.trim()
val birthYear =
    birthYearExtractionRegex.findFirstGroup(basePageResponseContent)?.replace("m.", "")
        ?.trim()?.toInt()

val fullNameAndAvatarMatch =
    fullNameAndAvatarExtractionRegex.find(basePageResponseContent)?.groupValues
val fullName = fullNameAndAvatarMatch?.get(1)?.trim()
val avatarUrl = fullNameAndAvatarMatch?.get(2)?.trim()

println(fullNameAndAvatarMatch)
println(fullName)
println(avatarUrl)
println(birthYear)
println(birthDate)
// Out:
// [id="user_img_id" class="profile-user-img img-responsive img-circle user-photo"         alt="Danila Gudim" src="/photos/20222136.jpg", Danila Gudim, /photos/20222136.jpg]
// Danila Gudim
// /photos/20222136.jpg
// 2004
// April 24

// %%
import kotlinx.datetime.TimeZone
import kotlinx.datetime.yearsUntil
import kotlin.time.Clock
import kotlin.time.Instant
import kotlinx.datetime.parse

@OptIn(kotlin.time.ExperimentalTime::class)
val currentYear = Instant.fromEpochMilliseconds(0) // Account for semester ending in the next year
    .yearsUntil(Clock.System.now().minus(40.days), TimeZone.currentSystemDefault())
    .plus(1970)

println(currentYear)
// Out:
// 2026

// %%
inline val Int.relSem
    get() = (this + 1) % 2 + 1

println(5.relSem)
println(6.relSem)
println(7.relSem)
println(8.relSem)
// Out:
// 1
// 2
// 1
// 2

// %%
@file:OptIn(ExperimentalTime::class)

import kotlinx.datetime.format.DateTimeComponents
import kotlinx.datetime.format.char
import kotlin.time.ExperimentalTime
import kotlinx.datetime.parse

var icsStr = """
        BEGIN:VCALENDAR
METHOD:PUBLISH
PRODID:-//Moodle Pty Ltd//NONSGML Moodle Version 2025041401.05//EN
VERSION:2.0
BEGIN:VEVENT
UID:181846@moodle.vilniustech.lt
SUMMARY:Theory Attendance
DESCRIPTION:Theory\n
CLASS:PUBLIC
LAST-MODIFIED:20260129T223941Z
DTSTAMP:20260425T201816Z
DTSTART:20260423T072000Z
DTEND:20260423T085500Z
CATEGORIES:FMISB23815\, O. O. Abayomi Alli (T/P)\, EN
END:VEVENT
BEGIN:VEVENT
UID:214168@moodle.vilniustech.lt
SUMMARY:PW8_Image Classification Task turi būti pateikta
DESCRIPTION:
CLASS:PUBLIC
LAST-MODIFIED:20260424T074641Z
DTSTAMP:20260425T201816Z
DTSTART:20260423T200000Z
DTEND:20260423T200000Z
CATEGORIES:FMISB23815\, O. O. Abayomi Alli (T/P)\, EN
END:VEVENT
BEGIN:VEVENT
UID:206961@moodle.vilniustech.lt
SUMMARY:Exam ITVf-22
DESCRIPTION:
CLASS:PUBLIC
LAST-MODIFIED:20260309T155036Z
LOCATION:206
DTSTAMP:20260425T201816Z
DTSTART:20260427T140000Z
DTEND:20260427T150000Z
CATEGORIES:ELKRB19801\, L. Duoba (T/L)\, EN
END:VEVENT
BEGIN:VEVENT
UID:206960@moodle.vilniustech.lt
SUMMARY:Exam ITVfu-22
DESCRIPTION:
CLASS:PUBLIC
LAST-MODIFIED:20260309T154940Z
LOCATION:206
DTSTAMP:20260425T201816Z
DTSTART:20260427T150000Z
DTEND:20260427T160000Z
CATEGORIES:ELKRB19801\, L. Duoba (T/L)\, EN
END:VEVENT
BEGIN:VEVENT
UID:106494@moodle.vilniustech.lt
SUMMARY:Homework 3 turi būti pateikta
DESCRIPTION:Depending on the topic and subject of the final thesis\, formul
	ate a task related to information security management that would complement
	 the theoretical and practical parts of the final thesis in the field of in
	formation security management. Prepare a report on the completed task accor
	ding to the Vilnius TECH\ntemplate.\n\nUPLOAD YOUR HOMEWORK.\n\nHW3 RATINGS
	 WILL BE LISTED HERE. \n\n

CLASS:PUBLIC
LAST-MODIFIED:20260318T145246Z
DTSTAMP:20260425T201816Z
DTSTART:20260429T144000Z
DTEND:20260429T144000Z
CATEGORIES:FMISB23800\, I. Šileikienė (T/P)
END:VEVENT
BEGIN:VEVENT
UID:20660@moodle.vilniustech.lt
SUMMARY:Research Essay Slides is due
DESCRIPTION:Upload the research essay slides before the presentation.\n
CLASS:PUBLIC
LAST-MODIFIED:20260325T122555Z
DTSTAMP:20260425T201816Z
DTSTART:20260429T210000Z
DTEND:20260429T210000Z
CATEGORIES:FMISB23800\, I. Šileikienė (T/P)
END:VEVENT
BEGIN:VEVENT
UID:103458@moodle.vilniustech.lt
SUMMARY:Research Essay is due
DESCRIPTION:Upload the research essay like Word or pdf document before the
	presentation.\n

CLASS:PUBLIC
LAST-MODIFIED:20260325T142255Z
DTSTAMP:20260425T201816Z
DTSTART:20260429T210000Z
DTEND:20260429T210000Z
CATEGORIES:FMISB23800\, I. Šileikienė (T/P)
END:VEVENT
BEGIN:VEVENT
UID:181885@moodle.vilniustech.lt
SUMMARY:Theory Attendance
DESCRIPTION:Practical Class (ITVfu-22)\n
CLASS:PUBLIC
LAST-MODIFIED:20260129T225457Z
DTSTAMP:20260425T201816Z
DTSTART:20260430T053000Z
DTEND:20260430T070500Z
CATEGORIES:FMISB23815\, O. O. Abayomi Alli (T/P)\, EN
END:VEVENT
BEGIN:VEVENT
UID:181847@moodle.vilniustech.lt
SUMMARY:Theory Attendance
DESCRIPTION:Theory\n
CLASS:PUBLIC
LAST-MODIFIED:20260129T223941Z
DTSTAMP:20260425T201816Z
DTSTART:20260430T072000Z
DTEND:20260430T085500Z
CATEGORIES:FMISB23815\, O. O. Abayomi Alli (T/P)\, EN
END:VEVENT
BEGIN:VEVENT
UID:181868@moodle.vilniustech.lt
SUMMARY:Theory Attendance
DESCRIPTION:Practical Class\n
CLASS:PUBLIC
LAST-MODIFIED:20260129T224117Z
DTSTAMP:20260425T201816Z
DTSTART:20260430T091000Z
DTEND:20260430T104500Z
CATEGORIES:FMISB23815\, O. O. Abayomi Alli (T/P)\, EN
END:VEVENT
BEGIN:VEVENT
UID:181886@moodle.vilniustech.lt
SUMMARY:Theory Attendance
DESCRIPTION:Practical Class (ITVfu-22)\n
CLASS:PUBLIC
LAST-MODIFIED:20260129T225457Z
DTSTAMP:20260425T201816Z
DTSTART:20260507T053000Z
DTEND:20260507T070500Z
CATEGORIES:FMISB23815\, O. O. Abayomi Alli (T/P)\, EN
END:VEVENT
BEGIN:VEVENT
UID:181848@moodle.vilniustech.lt
SUMMARY:Theory Attendance
DESCRIPTION:Theory\n
CLASS:PUBLIC
LAST-MODIFIED:20260129T223941Z
DTSTAMP:20260425T201816Z
DTSTART:20260507T072000Z
DTEND:20260507T085500Z
CATEGORIES:FMISB23815\, O. O. Abayomi Alli (T/P)\, EN
END:VEVENT
BEGIN:VEVENT
UID:181869@moodle.vilniustech.lt
SUMMARY:Theory Attendance
DESCRIPTION:Practical Class\n
CLASS:PUBLIC
LAST-MODIFIED:20260129T224117Z
DTSTAMP:20260425T201816Z
DTSTART:20260507T091000Z
DTEND:20260507T104500Z
CATEGORIES:FMISB23815\, O. O. Abayomi Alli (T/P)\, EN
END:VEVENT
BEGIN:VEVENT
UID:181887@moodle.vilniustech.lt
SUMMARY:Theory Attendance
DESCRIPTION:Practical Class (ITVfu-22)\n
CLASS:PUBLIC
LAST-MODIFIED:20260129T225457Z
DTSTAMP:20260425T201816Z
DTSTART:20260514T053000Z
DTEND:20260514T070500Z
CATEGORIES:FMISB23815\, O. O. Abayomi Alli (T/P)\, EN
END:VEVENT
BEGIN:VEVENT
UID:181849@moodle.vilniustech.lt
SUMMARY:Theory Attendance
DESCRIPTION:Theory\n
CLASS:PUBLIC
LAST-MODIFIED:20260129T223941Z
DTSTAMP:20260425T201816Z
DTSTART:20260514T072000Z
DTEND:20260514T085500Z
CATEGORIES:FMISB23815\, O. O. Abayomi Alli (T/P)\, EN
END:VEVENT
BEGIN:VEVENT
UID:181870@moodle.vilniustech.lt
SUMMARY:Theory Attendance
DESCRIPTION:Practical Class\n
CLASS:PUBLIC
LAST-MODIFIED:20260129T224117Z
DTSTAMP:20260425T201816Z
DTSTART:20260514T091000Z
DTEND:20260514T104500Z
CATEGORIES:FMISB23815\, O. O. Abayomi Alli (T/P)\, EN
END:VEVENT
BEGIN:VEVENT
UID:136491@moodle.vilniustech.lt
SUMMARY:Extra (NOT REQUIRED) turi būti pateikta
DESCRIPTION:Dedicated for specific purpose\, DO NOT REQUIRE ANY SUBMISSION\
	n\n

CLASS:PUBLIC
LAST-MODIFIED:20250903T205253Z
DTSTAMP:20260425T201816Z
DTSTART:20260519T003600Z
DTEND:20260519T003600Z
CATEGORIES:FMITB22705\, D. Shkundalov (T/P)\, EN
END:VEVENT
BEGIN:VEVENT
UID:181888@moodle.vilniustech.lt
SUMMARY:Theory Attendance
DESCRIPTION:Practical Class (ITVfu-22)\n
CLASS:PUBLIC
LAST-MODIFIED:20260129T225457Z
DTSTAMP:20260425T201816Z
DTSTART:20260521T053000Z
DTEND:20260521T070500Z
CATEGORIES:FMISB23815\, O. O. Abayomi Alli (T/P)\, EN
END:VEVENT
BEGIN:VEVENT
UID:181850@moodle.vilniustech.lt
SUMMARY:Theory Attendance
DESCRIPTION:Theory\n
CLASS:PUBLIC
LAST-MODIFIED:20260129T223941Z
DTSTAMP:20260425T201816Z
DTSTART:20260521T072000Z
DTEND:20260521T085500Z
CATEGORIES:FMISB23815\, O. O. Abayomi Alli (T/P)\, EN
END:VEVENT
BEGIN:VEVENT
UID:181871@moodle.vilniustech.lt
SUMMARY:Theory Attendance
DESCRIPTION:Practical Class\n
CLASS:PUBLIC
LAST-MODIFIED:20260129T224117Z
DTSTAMP:20260425T201816Z
DTSTART:20260521T091000Z
DTEND:20260521T104500Z
CATEGORIES:FMISB23815\, O. O. Abayomi Alli (T/P)\, EN
END:VEVENT
BEGIN:VEVENT
UID:181889@moodle.vilniustech.lt
SUMMARY:Theory Attendance
DESCRIPTION:Practical Class (ITVfu-22)\n
CLASS:PUBLIC
LAST-MODIFIED:20260129T225457Z
DTSTAMP:20260425T201816Z
DTSTART:20260528T053000Z
DTEND:20260528T070500Z
CATEGORIES:FMISB23815\, O. O. Abayomi Alli (T/P)\, EN
END:VEVENT
BEGIN:VEVENT
UID:181851@moodle.vilniustech.lt
SUMMARY:Theory Attendance
DESCRIPTION:Theory\n
CLASS:PUBLIC
LAST-MODIFIED:20260129T223941Z
DTSTAMP:20260425T201816Z
DTSTART:20260528T072000Z
DTEND:20260528T085500Z
CATEGORIES:FMISB23815\, O. O. Abayomi Alli (T/P)\, EN
END:VEVENT
BEGIN:VEVENT
UID:181872@moodle.vilniustech.lt
SUMMARY:Theory Attendance
DESCRIPTION:Practical Class\n
CLASS:PUBLIC
LAST-MODIFIED:20260129T224117Z
DTSTAMP:20260425T201816Z
DTSTART:20260528T091000Z
DTEND:20260528T104500Z
CATEGORIES:FMISB23815\, O. O. Abayomi Alli (T/P)\, EN
END:VEVENT
BEGIN:VEVENT
UID:181852@moodle.vilniustech.lt
SUMMARY:Theory Attendance
DESCRIPTION:Theory\n
CLASS:PUBLIC
LAST-MODIFIED:20260129T223941Z
DTSTAMP:20260425T201816Z
DTSTART:20260604T072000Z
DTEND:20260604T085500Z
CATEGORIES:FMISB23815\, O. O. Abayomi Alli (T/P)\, EN
END:VEVENT
BEGIN:VEVENT
UID:181853@moodle.vilniustech.lt
SUMMARY:Theory Attendance
DESCRIPTION:Theory\n
CLASS:PUBLIC
LAST-MODIFIED:20260129T223941Z
DTSTAMP:20260425T201816Z
DTSTART:20260611T072000Z
DTEND:20260611T085500Z
CATEGORIES:FMISB23815\, O. O. Abayomi Alli (T/P)\, EN
END:VEVENT
BEGIN:VEVENT
UID:181854@moodle.vilniustech.lt
SUMMARY:Theory Attendance
DESCRIPTION:Theory\n
CLASS:PUBLIC
LAST-MODIFIED:20260129T223941Z
DTSTAMP:20260425T201816Z
DTSTART:20260618T072000Z
DTEND:20260618T085500Z
CATEGORIES:FMISB23815\, O. O. Abayomi Alli (T/P)\, EN
END:VEVENT
END:VCALENDAR

        """

val iCalUTCFormat = DateTimeComponents.Format {
    year(); monthNumber(); day()
    char('T')
    hour(); minute(); second()
    char('Z')
}

var currentEventTitle = ""
var currentEventDescription = ""
var currentEventMoodleCourseId = 0L
var currentEventStart = Clock.System.now()
var currentEventEnd = Clock.System.now()

var inEvent = false

var currentLineBuffer = ""

for (line in icsStr.trim().split('\n')) {
    currentLineBuffer += line
        .replace("\t", "")
        .replace("\\n", "\n")
        .replace("\\", "")
    currentLineBuffer = currentLineBuffer.trim { it == ' ' || it == '\n' }
    // lines starting with tabs are continuations of the previous line
    if (line.startsWith("\t")) {
        println(currentLineBuffer)
        continue
    }

    if (currentLineBuffer == "BEGIN:VEVENT") {
        inEvent = true
    }
    if (currentLineBuffer == "END:VEVENT") {
        inEvent = false
//        println("EVENT ADDED!!: $currentEventDescription")
        currentEventTitle = ""
        currentEventDescription = ""
        currentEventMoodleCourseId = 0L
        currentEventStart = Clock.System.now()
        currentEventEnd = Clock.System.now()
    }
    if (inEvent) {
        when {
            currentLineBuffer.startsWith("UID:") -> {
                currentEventMoodleCourseId =
                    currentLineBuffer.removePrefix("UID:").split("@").first().toLong()
            }

            currentLineBuffer.startsWith("SUMMARY:") -> {
                currentEventTitle = currentLineBuffer.removePrefix("SUMMARY:")
            }

            currentLineBuffer.startsWith("DESCRIPTION:") -> {
                currentEventDescription = currentLineBuffer.removePrefix("DESCRIPTION:")
            }

            currentLineBuffer.startsWith("DTSTART:") -> {

                currentEventStart = Instant.parse(
                    currentLineBuffer.removePrefix("DTSTART:"),
                    iCalUTCFormat
                )
            }

            currentLineBuffer.startsWith("DTEND:") -> {
                currentEventEnd = Instant.parse(
                    currentLineBuffer.removePrefix("DTEND:"),
                    iCalUTCFormat
                )
            }
        }

    }
    currentLineBuffer = ""
}
// Out:
// 2026-05-28T05:30:00Z
// 2026-05-28T07:05:00Z

// %%
"".split(',').first()
