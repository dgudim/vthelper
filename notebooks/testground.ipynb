// %%
import io.ktor.client.plugins.cookies.AcceptAllCookiesStorage
import io.ktor.http.Cookie

val cookies = AcceptAllCookiesStorage()

fun AcceptAllCookiesStorage.test(): List<Cookie> {
    return container.map { it.cookie }
}

println(cookies.)
// Out:
// io.ktor.client.plugins.cookies.AcceptAllCookiesStorage@68a413a
